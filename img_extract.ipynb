# %%
import pandas as pd

train_df = pd.read_excel("data/train.xlsx")
test_df = pd.read_excel("data/test2.xlsx")

train_df[["id", "lat", "long"]].to_csv("train.csv", index=False)
test_df[["id", "lat", "long"]].to_csv("test.csv", index=False)
